# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("CarPrice.csv")
meta = pd.read_csv("MetaData.csv")

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %%
meta
# Out:
#      1                     Car_ID  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0    2                 Symboling          NaN         NaN         NaN
# 1    3                 carCompany         NaN         NaN         NaN
# 2    4                   fueltype         NaN         NaN         NaN
# 3    5                 aspiration         NaN         NaN         NaN
# 4    6                 doornumber         NaN         NaN         NaN
# 5    7                    carbody         NaN         NaN         NaN
# 6    8                 drivewheel         NaN         NaN         NaN
# 7    9             enginelocation         NaN         NaN         NaN
# 8   10                  wheelbase         NaN         NaN         NaN
# 9   11                  carlength         NaN         NaN         NaN
# 10  12                   carwidth         NaN         NaN         NaN
# 11  13                  carheight         NaN         NaN         NaN
# 12  14                 curbweight         NaN         NaN         NaN
# 13  15                 enginetype         NaN         NaN         NaN
# 14  16             cylindernumber         NaN         NaN         NaN
# 15  17                 enginesize         NaN         NaN         NaN
# 16  18                 fuelsystem         NaN         NaN         NaN
# 17  19                  boreratio         NaN         NaN         NaN
# 18  20                     stroke         NaN         NaN         NaN
# 19  21           compressionratio         NaN         NaN         NaN
# 20  22                 horsepower         NaN         NaN         NaN
# 21  23                    peakrpm         NaN         NaN         NaN
# 22  24                    citympg         NaN         NaN         NaN
# 23  25                 highwaympg         NaN         NaN         NaN
# 24  26  price(Dependent variable)         NaN         NaN         NaN
#
#              Unique id of each observation (Interger)  Unnamed: 6  Unnamed: 7
# 0   Its assigned insurance risk rating, A value of...         NaN         NaN
# 1                   Name of car company (Categorical)         NaN         NaN
# 2       Car fuel type i.e gas or diesel (Categorical)         NaN         NaN
# 3              Aspiration used in a car (Categorical)         NaN         NaN
# 4              Number of doors in a car (Categorical)         NaN         NaN
# 5                           body of car (Categorical)         NaN         NaN
# 6                   type of drive wheel (Categorical)         NaN         NaN
# 7                Location of car engine (Categorical)         NaN         NaN
# 8                           Weelbase of car (Numeric)         NaN         NaN
# 9                             Length of car (Numeric)         NaN         NaN
# 10                             Width of car (Numeric)         NaN         NaN
# 11                            height of car (Numeric)         NaN         NaN
# 12  The weight of a car without occupants or bagga...         NaN         NaN
# 13                      Type of engine. (Categorical)         NaN         NaN
# 14           cylinder placed in the car (Categorical)         NaN         NaN
# 15                              Size of car (Numeric)         NaN         NaN
# 16                   Fuel system of car (Categorical)         NaN         NaN
# 17                         Boreratio of car (Numeric)         NaN         NaN
# 18       Stroke or volume inside the engine (Numeric)         NaN         NaN
# 19                 compression ratio of car (Numeric)         NaN         NaN
# 20                               Horsepower (Numeric)         NaN         NaN
# 21                             car peak rpm (Numeric)         NaN         NaN
# 22                          Mileage in city (Numeric)         NaN         NaN
# 23                       Mileage on highway (Numeric)         NaN         NaN
# 24                             Price of car (Numeric)         NaN         NaN

# %%
##**Source: https://archive.ics.uci.edu/ml/datasets/Automobile
